# %% [markdown]
# <a href="https://colab.research.google.com/github/Leo-menezes-10/APIRD_RD/blob/main/kaggledatasetdwld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install kaggle
# !pip install kaggle --quiet

# %%
ls -ltr ~/.kaggle
# Out:
# total 4
# -rw-r--r-- 1 root root 67 May 10 12:23 'kaggle (1).json'

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s 'student_habits_performance.csv'
# Out:
# ref                                                          title                                          size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  ---------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# jayaantanaath/student-habits-vs-academic-performance         Student Habits vs Academic Performance        19512  2025-04-12 10:49:08.663000          65726        866                1
# nasasiratomowen/student-habits-performance-csv               student_habits_performance.csv                19512  2025-05-23 06:01:22.727000            274          0       0.23529412
# rajveers222/sutudenthabit                                    sutudenthabit                                 19512  2025-06-12 08:57:19.710000              5         10       0.23529412
# ...

# %%
# !kaggle datasets list -s 'student_habits_performance.csv'
# Out:
# ref                                                          title                                          size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  ---------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# jayaantanaath/student-habits-vs-academic-performance         Student Habits vs Academic Performance        19512  2025-04-12 10:49:08.663000          65726        866                1
# nasasiratomowen/student-habits-performance-csv               student_habits_performance.csv                19512  2025-05-23 06:01:22.727000            274          0       0.23529412
# rajveers222/sutudenthabit                                    sutudenthabit                                 19512  2025-06-12 08:57:19.710000              5         10       0.23529412
# ...

# %%
# Download and unzip the selected dataset
# !kaggle datasets download -d nasasiratomowen/student-habits-performance-csv -p ../data/kaggleDataSetforStudentHabits
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nasasiratomowen/student-habits-performance-csv
# License(s): CC0-1.0
# student-habits-performance-csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
ls -ltr ../data/kaggleDataSetforStudentHabits/
# Out:
# total 92
# -rwxrwxrwx 1 root root 19512 May 23  2025 student-habits-performance-csv.zip*
# -rwxrwxrwx 1 root root 73663 May 23  2025 student_habits_performance.csv*

# %%
# !chmod 777 ../data/kaggleDataSetforStudentHabits/student_habits_performance.csv

# %%
import pandas as pd

# Load the dataset into a pandas DataFrame
df = pd.read_csv('../data/kaggleDataSetforStudentHabits/student_habits_performance.csv')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
# !unzip ../data/kaggleDataSetforStudentHabits/student-habits-performance-csv.zip -d ../data/kaggleDataSetforStudentHabits/
# Out:
# Archive:  ../data/kaggleDataSetforStudentHabits/student-habits-performance-csv.zip
#   inflating: ../data/kaggleDataSetforStudentHabits/student_habits_performance.csv

# %%
import pandas as pd

# Load the dataset into a pandas DataFrame
df = pd.read_csv('student_habits_performance.csv')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
# Display information about the DataFrame (columns, types, non-null values)
print(df.info())

# Display descriptive statistics of the DataFrame
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
#upload kaggle.json file
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-bcd6d3c5-1dd9-4ecd-be90-d0eecce7d9ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bcd6d3c5-1dd9-4ecd-be90-d0eecce7d9ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#create kaggle directory
# !mkdir -p ~/.kaggle

# %%
#copy kaggle.json file
# !cp 'kaggle (1).json' ~/.kaggle/

# %%
#Set permissions for kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# List out all competitions after setting permissions
# !kaggle competitions list
# Out:
# You must authenticate before you can call the Kaggle API.
# Follow the instructions to authenticate at: https://github.com/Kaggle/kaggle-cli/blob/main/docs/README.md#authentication

# %%
#Rename the kaggle (1).json file to kaggle.json in the ~/.kaggle/ directory
# !mv ~/.kaggle/'kaggle (1).json' ~/.kaggle/kaggle.json

# %%
#Set permissions for the correctly named kaggle.json file
# !chmod 600 ~/.kaggle/kaggle.json

# %%
#List out all competitions after renaming and setting permissions
# !kaggle competitions list
# Out:
# ref                                                                              deadline             category         reward  teamCount  userHasEntered
# -------------------------------------------------------------------------------  -------------------  --------  -------------  ---------  --------------
# https://www.kaggle.com/competitions/passenger-screening-algorithm-challenge      2017-12-15 23:59:00  Featured  1,500,000 Usd        518           False
# https://www.kaggle.com/competitions/zillow-prize-1                               2018-01-10 15:59:00  Featured  1,200,000 Usd       3770           False
# https://www.kaggle.com/competitions/data-science-bowl-2017                       2017-04-12 23:59:00  Featured  1,000,000 Usd       1972           False
# https://www.kaggle.com/competitions/vesuvius-challenge-ink-detection             2023-06-14 23:59:00  Featured  1,000,000 Usd       1249           False
# ...

# %%
# List out all Kaggle datasets
# !kaggle datasets list
# Out:
# ref                                                                 title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# algozee/teenager-menthal-healy                                      Social Media Impact on Teen Mental Health                16190  2026-04-05 08:04:21.823000          22855        484                1
# sharmajicoder/gen-z-social-media-usage-dataset                      Gen-Z Social Media Usage Dataset                      44185801  2026-04-25 08:23:33.093000           2591         60                1
# ...
